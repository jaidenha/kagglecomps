# %%
# Planning Steps for this project:
# 1. import all relevant libraries and functions
# 2. read in data and then decide numerical_columns and categorical_columns
# 3. train test split X and y
# 4. define pipeline with preprocessors and XGBRegressor model
# 5. fit the model and make predictions
# 6. make improvements and then use all training data
# 7. submit (woohoo)

# %%
# 1.1 import general libraries

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import xgboost as xg
import joblib

# %%
# 1.2 import specific libraries

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# pipeline / preprocessing 
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# xgboost
from xgboost import XGBRegressor

# %%
# 2.1 read in the data

# %%
train_df = pd.read_csv(r"C:\Users\miria\OneDrive\Documents\DS Learn\practice datasets\kagglehousingpricesdata\train.csv")
test_df = pd.read_csv(r"C:\Users\miria\OneDrive\Documents\DS Learn\practice datasets\kagglehousingpricesdata\test.csv")

# %%
# 2.2 determine numerical_columns and categorical_columns features

# %%
numerical_columns = ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'PoolArea', 'YrSold', 'MoSold']
categorical_columns = ['Street', 'Alley', 'LotShape', 'Utilities', 'LotConfig', 'Neighborhood', 'ExterQual', 'Foundation', 'BsmtCond', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'Functional', 'GarageType', 'PoolQC', 'Fence', 'SaleCondition']
features = numerical_columns + categorical_columns

# %%
# 3.1 set X and y

# %%
X = train_df[features]
y = train_df[['SalePrice']]

# %%
# 3.2 train test split X and y

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

# %%
# 4.1 Set preprocessor for numerical data

# %%
numerical_transformer = SimpleImputer(strategy = 'constant').set_output(transform="pandas")

# %%
# 4.2 Set preprocessor for categorical data

# %%
categorical_transformer = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy = 'most_frequent')), 
    ('onehot', OneHotEncoder(handle_unknown = 'ignore', sparse_output = False))
]).set_output(transform="pandas")

# %%
# 4.3 bundle the preprocessors together

# %%
preprocessor = ColumnTransformer(transformers = [
    ('num', numerical_transformer, numerical_columns), 
    ('cat', categorical_transformer, categorical_columns)
]).set_output(transform="pandas")

# %%
# 4.4 set XGBRegressor model

# %%
my_model = XGBRegressor(n_estimators = 500, 
                        learning_rate = 0.05, 
                        random_state = 0,
                        early_stopping_rounds = 10,
                        enable_categorical = True
                        )

# %%
# use preprocessor on training data

# %%
encoder = preprocessor.fit(train_X)
train_X = encoder.transform(train_X)
val_X = encoder.transform(val_X)

# %%
# 5.1 fit the model, using early stopping rounds on a pipeline

# %%
my_model.fit(X = train_X, 
             y = train_y,
             eval_set = [(val_X, val_y)])
# Out:
# [0]	validation_0-rmse:77929.03440
# [1]	validation_0-rmse:74778.50371
# [2]	validation_0-rmse:71761.23248
# [3]	validation_0-rmse:69111.46696
# [4]	validation_0-rmse:66599.76096
# [5]	validation_0-rmse:64111.89112
# [6]	validation_0-rmse:61971.93466
# [7]	validation_0-rmse:59919.47904
# [8]	validation_0-rmse:57998.88474
# [9]	validation_0-rmse:56173.98456
# [10]	validation_0-rmse:54432.55296
# [11]	validation_0-rmse:52827.70599
# [12]	validation_0-rmse:51262.84428
# [13]	validation_0-rmse:49831.18695
# [14]	validation_0-rmse:48377.98695
# [15]	validation_0-rmse:47001.35468
# [16]	validation_0-rmse:45653.58627
# [17]	validation_0-rmse:44626.70119
# [18]	validation_0-rmse:43410.57262
# [19]	validation_0-rmse:42285.86983
# [20]	validation_0-rmse:41416.00345
# [21]	validation_0-rmse:40487.56258
# [22]	validation_0-rmse:39736.46765
# [23]	validation_0-rmse:38964.34223
# [24]	validation_0-rmse:38286.55196
# [25]	validation_0-rmse:37655.93722
# [26]	validation_0-rmse:37044.49299
# [27]	validation_0-rmse:36508.26317
# [28]	validation_0-rmse:36020.28862
# [29]	validation_0-rmse:35541.30087
# [30]	validation_0-rmse:35011.62450
# [31]	validation_0-rmse:34628.31119
# [32]	validation_0-rmse:34277.73295
# [33]	validation_0-rmse:33942.17796
# [34]	validation_0-rmse:33528.40780
# [35]	validation_0-rmse:33236.75531
# [36]	validation_0-rmse:33003.17974
# [37]	validation_0-rmse:32705.69472
# [38]	validation_0-rmse:32506.69415
# [39]	validation_0-rmse:32297.09659
# [40]	validation_0-rmse:32093.79825
# [41]	validation_0-rmse:31904.67314
# [42]	validation_0-rmse:31739.41524
# [43]	validation_0-rmse:31623.35370
# [44]	validation_0-rmse:31477.61328
# [45]	validation_0-rmse:31363.25094
# [46]	validation_0-rmse:31247.85731
# [47]	validation_0-rmse:31140.38176
# [48]	validation_0-rmse:31051.66652
# [49]	validation_0-rmse:30980.05283
# [50]	validation_0-rmse:30935.81733
# [51]	validation_0-rmse:30895.39626
# [52]	validation_0-rmse:30856.40444
# [53]	validation_0-rmse:30839.06179
# [54]	validation_0-rmse:30791.89233
# [55]	validation_0-rmse:30773.44000
# [56]	validation_0-rmse:30766.72240
# [57]	validation_0-rmse:30685.22959
# [58]	validation_0-rmse:30582.75537
# [59]	validation_0-rmse:30516.33458
# [60]	validation_0-rmse:30434.57285
# [61]	validation_0-rmse:30371.06955
# [62]	validation_0-rmse:30339.42442
# [63]	validation_0-rmse:30274.66281
# [64]	validation_0-rmse:30205.72373
# [65]	validation_0-rmse:30125.77283
# [66]	validation_0-rmse:30062.13900
# [67]	validation_0-rmse:30012.61203
# [68]	validation_0-rmse:29994.31299
# [69]	validation_0-rmse:29927.16450
# [70]	validation_0-rmse:29908.75064
# [71]	validation_0-rmse:29863.80725
# [72]	validation_0-rmse:29816.03505
# [73]	validation_0-rmse:29759.53398
# [74]	validation_0-rmse:29692.39736
# [75]	validation_0-rmse:29667.93002
# [76]	validation_0-rmse:29621.47792
# [77]	validation_0-rmse:29557.86296
# [78]	validation_0-rmse:29512.88200
# [79]	validation_0-rmse:29488.90322
# [80]	validation_0-rmse:29466.78072
# [81]	validation_0-rmse:29424.47124
# [82]	validation_0-rmse:29385.46019
# [83]	validation_0-rmse:29345.03243
# [84]	validation_0-rmse:29301.52017
# [85]	validation_0-rmse:29273.93238
# [86]	validation_0-rmse:29250.98980
# [87]	validation_0-rmse:29208.64470
# [88]	validation_0-rmse:29182.73296
# [89]	validation_0-rmse:29176.28911
# [90]	validation_0-rmse:29118.11245
# [91]	validation_0-rmse:29111.42562
# [92]	validation_0-rmse:29096.57272
# [93]	validation_0-rmse:29079.86931
# [94]	validation_0-rmse:29031.48005
# [95]	validation_0-rmse:29027.98937
# [96]	validation_0-rmse:29024.04761
# [97]	validation_0-rmse:29014.72253
# [98]	validation_0-rmse:28996.55993
# [99]	validation_0-rmse:28978.97271
# [100]	validation_0-rmse:28960.18590
# [101]	validation_0-rmse:28954.04285
# [102]	validation_0-rmse:28961.97076
# [103]	validation_0-rmse:28958.47367
# [104]	validation_0-rmse:28949.59133
# [105]	validation_0-rmse:28952.38146
# [106]	validation_0-rmse:28935.32529
# [107]	validation_0-rmse:28935.01835
# [108]	validation_0-rmse:28936.65985
# [109]	validation_0-rmse:28932.07801
# [110]	validation_0-rmse:28914.74448
# [111]	validation_0-rmse:28914.15057
# [112]	validation_0-rmse:28908.78578
# [113]	validation_0-rmse:28892.28276
# [114]	validation_0-rmse:28908.58906
# [115]	validation_0-rmse:28896.71188
# [116]	validation_0-rmse:28897.03141
# [117]	validation_0-rmse:28887.90600
# [118]	validation_0-rmse:28880.80195
# [119]	validation_0-rmse:28868.01255
# [120]	validation_0-rmse:28863.22695
# [121]	validation_0-rmse:28876.37874
# [122]	validation_0-rmse:28867.86512
# [123]	validation_0-rmse:28856.72357
# [124]	validation_0-rmse:28852.65803
# [125]	validation_0-rmse:28839.90600
# [126]	validation_0-rmse:28854.99949
# [127]	validation_0-rmse:28850.92174
# [128]	validation_0-rmse:28833.38098
# [129]	validation_0-rmse:28840.14177
# [130]	validation_0-rmse:28848.25597
# [131]	validation_0-rmse:28840.98622
# [132]	validation_0-rmse:28839.02176
# [133]	validation_0-rmse:28848.20858
# [134]	validation_0-rmse:28842.99300
# [135]	validation_0-rmse:28827.80804
# [136]	validation_0-rmse:28822.36962
# [137]	validation_0-rmse:28831.76768
# [138]	validation_0-rmse:28829.07900
# [139]	validation_0-rmse:28825.98431
# [140]	validation_0-rmse:28815.47258
# [141]	validation_0-rmse:28810.71866
# [142]	validation_0-rmse:28809.66285
# [143]	validation_0-rmse:28792.20203
# [144]	validation_0-rmse:28788.88744
# [145]	validation_0-rmse:28791.11248
# [146]	validation_0-rmse:28782.77634
# [147]	validation_0-rmse:28778.57604
# [148]	validation_0-rmse:28774.12518
# [149]	validation_0-rmse:28780.06642
# [150]	validation_0-rmse:28779.23468
# [151]	validation_0-rmse:28771.79061
# [152]	validation_0-rmse:28767.36460
# [153]	validation_0-rmse:28769.74678
# [154]	validation_0-rmse:28768.58799
# [155]	validation_0-rmse:28763.14309
# [156]	validation_0-rmse:28751.16451
# [157]	validation_0-rmse:28754.77394
# [158]	validation_0-rmse:28757.90301
# [159]	validation_0-rmse:28763.05325
# [160]	validation_0-rmse:28764.05263
# [161]	validation_0-rmse:28779.61448
# [162]	validation_0-rmse:28773.01564
# [163]	validation_0-rmse:28770.80020
# [164]	validation_0-rmse:28765.09651
# [165]	validation_0-rmse:28769.47474
# [166]	validation_0-rmse:28759.65232
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=10,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=0, ...)

# %%
# 5.2 make predictions using the model

# %%
predictions = my_model.predict(val_X)

# %%
# 5.3 get mean absolute error

# %%
initial_mae = mean_absolute_error(predictions, val_y)
print(initial_mae)
# Out:
# 17833.93486729452

# %%
# 6.1 use preprocessor on all training data

# %%
all_encoder = preprocessor.fit(X)
X = all_encoder.transform(X)
X = X.drop(['cat__Utilities_NoSeWa', 'cat__Heating_Floor', 'cat__Heating_OthW', 'cat__Electrical_Mix', 'cat__PoolQC_Fa'], axis=1)

# %%
# 6.2 fit the model on all training data

# %%
my_model.fit(X = X,
             y = y,
             eval_set = [(X, y)])
# Out:
# [0]	validation_0-rmse:76109.64422
# [1]	validation_0-rmse:72996.42853
# [2]	validation_0-rmse:70046.57316
# [3]	validation_0-rmse:67245.04094
# [4]	validation_0-rmse:64572.78212
# [5]	validation_0-rmse:62036.06241
# [6]	validation_0-rmse:59615.59204
# [7]	validation_0-rmse:57337.40322
# [8]	validation_0-rmse:55168.07293
# [9]	validation_0-rmse:53081.02254
# [10]	validation_0-rmse:51113.04684
# [11]	validation_0-rmse:49222.58261
# [12]	validation_0-rmse:47376.11394
# [13]	validation_0-rmse:45613.75194
# [14]	validation_0-rmse:44010.84106
# [15]	validation_0-rmse:42429.95087
# [16]	validation_0-rmse:40931.64599
# [17]	validation_0-rmse:39545.72632
# [18]	validation_0-rmse:38243.89913
# [19]	validation_0-rmse:36947.03624
# [20]	validation_0-rmse:35741.35637
# [21]	validation_0-rmse:34556.36780
# [22]	validation_0-rmse:33471.74139
# [23]	validation_0-rmse:32449.91874
# [24]	validation_0-rmse:31487.94348
# [25]	validation_0-rmse:30566.57826
# [26]	validation_0-rmse:29674.31090
# [27]	validation_0-rmse:28779.53064
# [28]	validation_0-rmse:27962.72945
# [29]	validation_0-rmse:27223.54584
# [30]	validation_0-rmse:26503.02386
# [31]	validation_0-rmse:25815.64684
# [32]	validation_0-rmse:25151.74537
# [33]	validation_0-rmse:24494.69002
# [34]	validation_0-rmse:23867.17670
# [35]	validation_0-rmse:23307.60370
# [36]	validation_0-rmse:22745.18478
# [37]	validation_0-rmse:22218.56503
# [38]	validation_0-rmse:21713.75349
# [39]	validation_0-rmse:21223.21061
# [40]	validation_0-rmse:20796.99986
# [41]	validation_0-rmse:20361.73140
# [42]	validation_0-rmse:19951.41871
# [43]	validation_0-rmse:19521.28438
# [44]	validation_0-rmse:19157.91799
# [45]	validation_0-rmse:18774.02930
# [46]	validation_0-rmse:18447.04804
# [47]	validation_0-rmse:18097.44296
# [48]	validation_0-rmse:17765.61310
# [49]	validation_0-rmse:17448.85903
# [50]	validation_0-rmse:17176.60727
# [51]	validation_0-rmse:16884.90113
# [52]	validation_0-rmse:16606.67675
# [53]	validation_0-rmse:16361.11350
# [54]	validation_0-rmse:16116.27848
# [55]	validation_0-rmse:15864.97629
# [56]	validation_0-rmse:15615.64351
# [57]	validation_0-rmse:15376.06666
# [58]	validation_0-rmse:15149.03679
# [59]	validation_0-rmse:14953.12367
# [60]	validation_0-rmse:14745.92228
# [61]	validation_0-rmse:14560.73199
# [62]	validation_0-rmse:14392.82348
# [63]	validation_0-rmse:14220.27208
# [64]	validation_0-rmse:14052.49862
# [65]	validation_0-rmse:13884.95810
# [66]	validation_0-rmse:13734.21468
# [67]	validation_0-rmse:13605.02042
# [68]	validation_0-rmse:13452.81279
# [69]	validation_0-rmse:13337.27450
# [70]	validation_0-rmse:13191.30904
# [71]	validation_0-rmse:13058.95462
# [72]	validation_0-rmse:12950.47120
# [73]	validation_0-rmse:12834.49242
# [74]	validation_0-rmse:12721.89043
# [75]	validation_0-rmse:12614.44753
# [76]	validation_0-rmse:12523.56499
# [77]	validation_0-rmse:12426.03819
# [78]	validation_0-rmse:12340.08620
# [79]	validation_0-rmse:12249.11941
# [80]	validation_0-rmse:12158.51220
# [81]	validation_0-rmse:12059.36321
# [82]	validation_0-rmse:11987.48807
# [83]	validation_0-rmse:11893.73531
# [84]	validation_0-rmse:11830.16077
# [85]	validation_0-rmse:11752.32053
# [86]	validation_0-rmse:11687.71401
# [87]	validation_0-rmse:11625.24387
# [88]	validation_0-rmse:11570.56160
# [89]	validation_0-rmse:11496.16888
# [90]	validation_0-rmse:11437.33786
# [91]	validation_0-rmse:11385.03841
# [92]	validation_0-rmse:11335.98544
# [93]	validation_0-rmse:11298.17626
# [94]	validation_0-rmse:11245.84549
# [95]	validation_0-rmse:11209.63020
# [96]	validation_0-rmse:11155.79098
# [97]	validation_0-rmse:11102.76527
# [98]	validation_0-rmse:11062.66056
# [99]	validation_0-rmse:11024.41935
# [100]	validation_0-rmse:10975.72000
# [101]	validation_0-rmse:10922.19011
# [102]	validation_0-rmse:10885.12108
# [103]	validation_0-rmse:10811.63172
# [104]	validation_0-rmse:10770.90207
# [105]	validation_0-rmse:10732.78846
# [106]	validation_0-rmse:10696.14318
# [107]	validation_0-rmse:10670.34944
# [108]	validation_0-rmse:10644.95040
# [109]	validation_0-rmse:10621.82235
# [110]	validation_0-rmse:10566.94018
# [111]	validation_0-rmse:10541.13925
# [112]	validation_0-rmse:10525.80382
# [113]	validation_0-rmse:10474.49600
# [114]	validation_0-rmse:10458.74051
# [115]	validation_0-rmse:10429.09861
# [116]	validation_0-rmse:10385.54615
# [117]	validation_0-rmse:10362.87660
# [118]	validation_0-rmse:10318.03569
# [119]	validation_0-rmse:10275.28823
# [120]	validation_0-rmse:10260.71616
# [121]	validation_0-rmse:10237.26223
# [122]	validation_0-rmse:10217.83139
# [123]	validation_0-rmse:10172.37083
# [124]	validation_0-rmse:10156.72778
# [125]	validation_0-rmse:10133.46855
# [126]	validation_0-rmse:10106.57960
# [127]	validation_0-rmse:10082.64522
# [128]	validation_0-rmse:10070.51579
# [129]	validation_0-rmse:10033.94807
# [130]	validation_0-rmse:9999.29462
# [131]	validation_0-rmse:9975.80838
# [132]	validation_0-rmse:9950.52438
# [133]	validation_0-rmse:9931.54024
# [134]	validation_0-rmse:9905.17892
# [135]	validation_0-rmse:9874.88028
# [136]	validation_0-rmse:9844.07863
# [137]	validation_0-rmse:9806.27632
# [138]	validation_0-rmse:9788.92656
# [139]	validation_0-rmse:9763.29214
# [140]	validation_0-rmse:9743.28288
# [141]	validation_0-rmse:9717.40299
# [142]	validation_0-rmse:9708.36184
# [143]	validation_0-rmse:9687.34430
# [144]	validation_0-rmse:9671.77041
# [145]	validation_0-rmse:9658.61920
# [146]	validation_0-rmse:9634.53092
# [147]	validation_0-rmse:9613.03386
# [148]	validation_0-rmse:9592.71213
# [149]	validation_0-rmse:9567.89827
# [150]	validation_0-rmse:9560.00522
# [151]	validation_0-rmse:9548.39988
# [152]	validation_0-rmse:9523.78716
# [153]	validation_0-rmse:9489.97144
# [154]	validation_0-rmse:9482.99282
# [155]	validation_0-rmse:9443.81165
# [156]	validation_0-rmse:9422.21250
# [157]	validation_0-rmse:9403.60979
# [158]	validation_0-rmse:9386.60936
# [159]	validation_0-rmse:9361.26222
# [160]	validation_0-rmse:9339.16312
# [161]	validation_0-rmse:9306.99439
# [162]	validation_0-rmse:9285.27164
# [163]	validation_0-rmse:9269.55635
# [164]	validation_0-rmse:9253.78352
# [165]	validation_0-rmse:9232.03478
# [166]	validation_0-rmse:9222.71485
# [167]	validation_0-rmse:9203.26161
# [168]	validation_0-rmse:9185.67772
# [169]	validation_0-rmse:9166.09758
# [170]	validation_0-rmse:9155.81663
# [171]	validation_0-rmse:9120.44168
# [172]	validation_0-rmse:9110.60691
# [173]	validation_0-rmse:9085.50301
# [174]	validation_0-rmse:9071.85078
# [175]	validation_0-rmse:9029.49165
# [176]	validation_0-rmse:9009.86654
# [177]	validation_0-rmse:8982.25221
# [178]	validation_0-rmse:8976.66188
# [179]	validation_0-rmse:8946.43592
# [180]	validation_0-rmse:8934.69339
# [181]	validation_0-rmse:8917.87732
# [182]	validation_0-rmse:8886.11969
# [183]	validation_0-rmse:8861.12903
# [184]	validation_0-rmse:8844.53275
# [185]	validation_0-rmse:8837.14408
# [186]	validation_0-rmse:8818.87536
# [187]	validation_0-rmse:8786.44467
# [188]	validation_0-rmse:8773.37079
# [189]	validation_0-rmse:8757.94764
# [190]	validation_0-rmse:8726.26999
# [191]	validation_0-rmse:8713.58764
# [192]	validation_0-rmse:8683.59755
# [193]	validation_0-rmse:8652.69010
# [194]	validation_0-rmse:8638.25533
# [195]	validation_0-rmse:8612.79805
# [196]	validation_0-rmse:8597.24385
# [197]	validation_0-rmse:8574.53478
# [198]	validation_0-rmse:8553.04509
# [199]	validation_0-rmse:8531.04725
# [200]	validation_0-rmse:8521.33139
# [201]	validation_0-rmse:8502.27251
# [202]	validation_0-rmse:8478.39320
# [203]	validation_0-rmse:8453.92528
# [204]	validation_0-rmse:8430.37343
# [205]	validation_0-rmse:8418.04451
# [206]	validation_0-rmse:8404.82649
# [207]	validation_0-rmse:8380.90266
# [208]	validation_0-rmse:8336.05829
# [209]	validation_0-rmse:8322.53452
# [210]	validation_0-rmse:8293.98857
# [211]	validation_0-rmse:8277.05668
# [212]	validation_0-rmse:8248.55498
# [213]	validation_0-rmse:8225.02963
# [214]	validation_0-rmse:8194.04911
# [215]	validation_0-rmse:8181.76419
# [216]	validation_0-rmse:8160.14245
# [217]	validation_0-rmse:8147.91111
# [218]	validation_0-rmse:8094.84372
# [219]	validation_0-rmse:8058.24907
# [220]	validation_0-rmse:8049.32921
# [221]	validation_0-rmse:8035.20297
# [222]	validation_0-rmse:8018.57255
# [223]	validation_0-rmse:8005.12620
# [224]	validation_0-rmse:7994.06105
# [225]	validation_0-rmse:7963.70643
# [226]	validation_0-rmse:7943.06994
# [227]	validation_0-rmse:7892.82387
# [228]	validation_0-rmse:7878.19743
# [229]	validation_0-rmse:7862.24975
# [230]	validation_0-rmse:7851.50915
# [231]	validation_0-rmse:7836.38032
# [232]	validation_0-rmse:7822.09621
# [233]	validation_0-rmse:7805.66913
# [234]	validation_0-rmse:7791.12561
# [235]	validation_0-rmse:7779.16396
# [236]	validation_0-rmse:7767.52776
# [237]	validation_0-rmse:7759.21855
# [238]	validation_0-rmse:7736.51438
# [239]	validation_0-rmse:7719.82316
# [240]	validation_0-rmse:7710.17539
# [241]	validation_0-rmse:7705.03506
# [242]	validation_0-rmse:7688.48544
# [243]	validation_0-rmse:7682.65374
# [244]	validation_0-rmse:7666.16876
# [245]	validation_0-rmse:7642.29369
# [246]	validation_0-rmse:7628.78811
# [247]	validation_0-rmse:7582.44668
# [248]	validation_0-rmse:7575.07828
# [249]	validation_0-rmse:7550.69764
# [250]	validation_0-rmse:7541.96733
# [251]	validation_0-rmse:7508.68046
# [252]	validation_0-rmse:7495.88509
# [253]	validation_0-rmse:7462.68190
# [254]	validation_0-rmse:7434.44792
# [255]	validation_0-rmse:7413.44756
# [256]	validation_0-rmse:7398.16172
# [257]	validation_0-rmse:7386.39408
# [258]	validation_0-rmse:7362.44708
# [259]	validation_0-rmse:7345.21966
# [260]	validation_0-rmse:7333.98420
# [261]	validation_0-rmse:7314.73965
# [262]	validation_0-rmse:7310.07143
# [263]	validation_0-rmse:7299.08879
# [264]	validation_0-rmse:7290.39803
# [265]	validation_0-rmse:7281.48399
# [266]	validation_0-rmse:7256.24460
# [267]	validation_0-rmse:7246.21117
# [268]	validation_0-rmse:7229.13339
# [269]	validation_0-rmse:7215.73208
# [270]	validation_0-rmse:7203.41457
# [271]	validation_0-rmse:7191.67934
# [272]	validation_0-rmse:7180.72621
# [273]	validation_0-rmse:7171.21594
# [274]	validation_0-rmse:7153.39128
# [275]	validation_0-rmse:7142.34552
# [276]	validation_0-rmse:7132.09493
# [277]	validation_0-rmse:7114.47110
# [278]	validation_0-rmse:7089.31888
# [279]	validation_0-rmse:7074.10919
# [280]	validation_0-rmse:7037.43457
# [281]	validation_0-rmse:7016.43753
# [282]	validation_0-rmse:6994.90289
# [283]	validation_0-rmse:6988.36875
# [284]	validation_0-rmse:6958.75312
# [285]	validation_0-rmse:6946.87652
# [286]	validation_0-rmse:6930.97108
# [287]	validation_0-rmse:6920.27080
# [288]	validation_0-rmse:6896.88960
# [289]	validation_0-rmse:6890.07198
# [290]	validation_0-rmse:6855.63029
# [291]	validation_0-rmse:6845.97047
# [292]	validation_0-rmse:6822.01569
# [293]	validation_0-rmse:6809.16561
# [294]	validation_0-rmse:6794.75025
# [295]	validation_0-rmse:6760.05951
# [296]	validation_0-rmse:6750.92730
# [297]	validation_0-rmse:6734.41605
# [298]	validation_0-rmse:6712.53200
# [299]	validation_0-rmse:6703.64437
# [300]	validation_0-rmse:6680.64619
# [301]	validation_0-rmse:6663.00055
# [302]	validation_0-rmse:6660.83254
# [303]	validation_0-rmse:6649.99745
# [304]	validation_0-rmse:6618.51111
# [305]	validation_0-rmse:6607.72558
# [306]	validation_0-rmse:6578.05317
# [307]	validation_0-rmse:6552.62840
# [308]	validation_0-rmse:6540.95131
# [309]	validation_0-rmse:6528.59884
# [310]	validation_0-rmse:6521.51405
# [311]	validation_0-rmse:6502.12507
# [312]	validation_0-rmse:6493.35167
# [313]	validation_0-rmse:6479.33472
# [314]	validation_0-rmse:6459.99937
# [315]	validation_0-rmse:6436.34608
# [316]	validation_0-rmse:6417.43392
# [317]	validation_0-rmse:6397.88908
# [318]	validation_0-rmse:6393.86379
# [319]	validation_0-rmse:6372.56861
# [320]	validation_0-rmse:6364.22406
# [321]	validation_0-rmse:6345.80131
# [322]	validation_0-rmse:6330.43234
# [323]	validation_0-rmse:6313.64193
# [324]	validation_0-rmse:6291.94546
# [325]	validation_0-rmse:6278.52202
# [326]	validation_0-rmse:6253.00860
# [327]	validation_0-rmse:6248.60988
# [328]	validation_0-rmse:6224.86684
# [329]	validation_0-rmse:6198.78479
# [330]	validation_0-rmse:6176.94063
# [331]	validation_0-rmse:6158.82486
# [332]	validation_0-rmse:6146.00237
# [333]	validation_0-rmse:6138.27629
# [334]	validation_0-rmse:6107.48577
# [335]	validation_0-rmse:6091.59436
# [336]	validation_0-rmse:6083.44784
# [337]	validation_0-rmse:6057.11209
# [338]	validation_0-rmse:6035.11761
# [339]	validation_0-rmse:6010.07553
# [340]	validation_0-rmse:5991.50476
# [341]	validation_0-rmse:5973.10077
# [342]	validation_0-rmse:5967.46356
# [343]	validation_0-rmse:5946.15271
# [344]	validation_0-rmse:5940.00470
# [345]	validation_0-rmse:5925.19373
# [346]	validation_0-rmse:5905.08272
# [347]	validation_0-rmse:5881.91315
# [348]	validation_0-rmse:5871.51648
# [349]	validation_0-rmse:5864.41032
# [350]	validation_0-rmse:5858.67287
# [351]	validation_0-rmse:5850.89622
# [352]	validation_0-rmse:5840.78736
# [353]	validation_0-rmse:5824.69116
# [354]	validation_0-rmse:5817.89112
# [355]	validation_0-rmse:5799.57055
# [356]	validation_0-rmse:5786.69193
# [357]	validation_0-rmse:5762.18400
# [358]	validation_0-rmse:5747.28707
# [359]	validation_0-rmse:5715.53790
# [360]	validation_0-rmse:5702.71545
# [361]	validation_0-rmse:5699.58976
# [362]	validation_0-rmse:5694.17871
# [363]	validation_0-rmse:5674.62268
# [364]	validation_0-rmse:5669.40706
# [365]	validation_0-rmse:5662.63745
# [366]	validation_0-rmse:5642.67029
# [367]	validation_0-rmse:5637.12375
# [368]	validation_0-rmse:5615.99228
# [369]	validation_0-rmse:5610.91171
# [370]	validation_0-rmse:5607.61272
# [371]	validation_0-rmse:5587.54370
# [372]	validation_0-rmse:5572.89781
# [373]	validation_0-rmse:5545.22932
# [374]	validation_0-rmse:5539.26336
# [375]	validation_0-rmse:5531.07152
# [376]	validation_0-rmse:5521.89870
# [377]	validation_0-rmse:5517.15269
# [378]	validation_0-rmse:5508.97578
# [379]	validation_0-rmse:5499.47605
# [380]	validation_0-rmse:5487.88278
# [381]	validation_0-rmse:5479.68499
# [382]	validation_0-rmse:5470.71801
# [383]	validation_0-rmse:5450.83033
# [384]	validation_0-rmse:5429.97002
# [385]	validation_0-rmse:5426.98567
# [386]	validation_0-rmse:5407.60172
# [387]	validation_0-rmse:5401.99320
# [388]	validation_0-rmse:5393.03343
# [389]	validation_0-rmse:5371.07208
# [390]	validation_0-rmse:5364.11402
# [391]	validation_0-rmse:5355.05143
# [392]	validation_0-rmse:5349.94376
# [393]	validation_0-rmse:5346.19660
# [394]	validation_0-rmse:5323.74924
# [395]	validation_0-rmse:5300.83975
# [396]	validation_0-rmse:5294.71099
# [397]	validation_0-rmse:5284.94075
# [398]	validation_0-rmse:5282.59509
# [399]	validation_0-rmse:5275.21409
# [400]	validation_0-rmse:5260.63913
# [401]	validation_0-rmse:5239.07302
# [402]	validation_0-rmse:5223.10256
# [403]	validation_0-rmse:5217.73454
# [404]	validation_0-rmse:5199.40597
# [405]	validation_0-rmse:5161.82381
# [406]	validation_0-rmse:5146.15139
# [407]	validation_0-rmse:5141.04067
# [408]	validation_0-rmse:5137.20604
# [409]	validation_0-rmse:5131.45784
# [410]	validation_0-rmse:5126.68562
# [411]	validation_0-rmse:5122.96444
# [412]	validation_0-rmse:5116.04053
# [413]	validation_0-rmse:5114.13771
# [414]	validation_0-rmse:5104.28479
# [415]	validation_0-rmse:5100.39469
# [416]	validation_0-rmse:5097.44144
# [417]	validation_0-rmse:5084.36011
# [418]	validation_0-rmse:5071.69764
# [419]	validation_0-rmse:5038.70855
# [420]	validation_0-rmse:5033.38113
# [421]	validation_0-rmse:5019.88500
# [422]	validation_0-rmse:4996.30760
# [423]	validation_0-rmse:4983.98368
# [424]	validation_0-rmse:4972.48012
# [425]	validation_0-rmse:4952.33466
# [426]	validation_0-rmse:4941.08088
# [427]	validation_0-rmse:4928.54415
# [428]	validation_0-rmse:4924.24159
# [429]	validation_0-rmse:4921.25287
# [430]	validation_0-rmse:4915.16983
# [431]	validation_0-rmse:4893.95979
# [432]	validation_0-rmse:4888.95689
# [433]	validation_0-rmse:4884.92013
# [434]	validation_0-rmse:4880.23236
# [435]	validation_0-rmse:4874.97536
# [436]	validation_0-rmse:4873.40527
# [437]	validation_0-rmse:4856.23257
# [438]	validation_0-rmse:4852.32507
# [439]	validation_0-rmse:4849.53335
# [440]	validation_0-rmse:4840.62082
# [441]	validation_0-rmse:4824.86152
# [442]	validation_0-rmse:4815.02563
# [443]	validation_0-rmse:4809.59793
# [444]	validation_0-rmse:4795.81419
# [445]	validation_0-rmse:4793.03986
# [446]	validation_0-rmse:4766.66947
# [447]	validation_0-rmse:4731.65997
# [448]	validation_0-rmse:4714.17835
# [449]	validation_0-rmse:4693.08095
# [450]	validation_0-rmse:4678.50934
# [451]	validation_0-rmse:4665.98875
# [452]	validation_0-rmse:4650.90343
# [453]	validation_0-rmse:4625.35639
# [454]	validation_0-rmse:4605.77339
# [455]	validation_0-rmse:4603.21015
# [456]	validation_0-rmse:4585.07229
# [457]	validation_0-rmse:4571.89868
# [458]	validation_0-rmse:4560.59710
# [459]	validation_0-rmse:4544.72144
# [460]	validation_0-rmse:4523.87168
# [461]	validation_0-rmse:4504.48054
# [462]	validation_0-rmse:4493.18543
# [463]	validation_0-rmse:4477.83235
# [464]	validation_0-rmse:4462.88151
# [465]	validation_0-rmse:4454.36652
# [466]	validation_0-rmse:4449.67571
# [467]	validation_0-rmse:4439.69191
# [468]	validation_0-rmse:4431.96856
# [469]	validation_0-rmse:4408.52403
# [470]	validation_0-rmse:4386.66814
# [471]	validation_0-rmse:4374.07674
# [472]	validation_0-rmse:4365.98574
# [473]	validation_0-rmse:4357.55221
# [474]	validation_0-rmse:4334.65880
# [475]	validation_0-rmse:4328.98876
# [476]	validation_0-rmse:4308.12562
# [477]	validation_0-rmse:4303.36393
# [478]	validation_0-rmse:4294.75779
# [479]	validation_0-rmse:4286.62605
# [480]	validation_0-rmse:4272.40704
# [481]	validation_0-rmse:4267.45799
# [482]	validation_0-rmse:4260.13425
# [483]	validation_0-rmse:4255.48115
# [484]	validation_0-rmse:4247.44900
# [485]	validation_0-rmse:4229.18468
# [486]	validation_0-rmse:4227.35576
# [487]	validation_0-rmse:4217.83203
# [488]	validation_0-rmse:4211.85471
# [489]	validation_0-rmse:4201.61743
# [490]	validation_0-rmse:4179.24809
# [491]	validation_0-rmse:4160.07299
# [492]	validation_0-rmse:4151.42478
# [493]	validation_0-rmse:4139.10232
# [494]	validation_0-rmse:4118.08772
# [495]	validation_0-rmse:4104.18456
# [496]	validation_0-rmse:4089.24903
# [497]	validation_0-rmse:4079.66761
# [498]	validation_0-rmse:4067.65192
# [499]	validation_0-rmse:4054.74246
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=10,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=0, ...)

# %%
# 6.3 make predictions on test data

# %%
test_X = test_df[features]

test_encoder = preprocessor.fit(test_X)
test_X = test_encoder.transform(test_X)

test_preds = my_model.predict(test_X, validate_features = False)

# %%
# 7 submit

# %%
output = pd.DataFrame({'Id': test_df.Id, 'SalePrice': test_preds})
output.to_csv(r"C:\Users\miria\OneDrive\Documents\DS Learn\output datasets\kagglehousepricessubmission2.csv", index=False)

# %%
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 80, dtype: object
